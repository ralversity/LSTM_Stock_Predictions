# %%
# %run user_interface.ipynb
# Out:
# Enter your choice for what you'd like to do:
#             1. Run LSTM program on a stock of your choice
#             2. See current stock files in data folder and select a file to see data
#             3. Exit Program
#             2
#
# The files available in the data folder are:
# AAPL_predictions.png
# GOOG_predictions.png
# Enter the file name you'd like to see the data of
#                          (Example input: GOOG_predictions.png): GOOG_predictions.png
#
#
# Would you like to look at another model(Y/N)?: y
#
# The files available in the data folder are:
# AAPL_predictions.png
# GOOG_predictions.png
# Enter the file name you'd like to see the data of
#                          (Example input: GOOG_predictions.png): AAPL_predictions.png
#
#
# Would you like to look at another model(Y/N)?: n
# Enter your choice for what you'd like to do:
#             1. Run LSTM program on a stock of your choice
# ...
